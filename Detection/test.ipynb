# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
random_seed = 1010

data = pd.read_csv('E:\Malicious-URL-detection\MaliciousURLDataset\MaliciousURLsProcessed.csv')

# %%
df = pd.DataFrame(data)
X = df.iloc[:,0]
y = df.iloc[:,1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed, stratify=y)

# %%
df.head()
# Out:
#                                                  url        type  url_type  \
# 0                                   br-icloud.com.br    phishing         2
# 1                mp3raid.com/music/krizz_kaliko.html      benign         0
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign         0
# 3  http://garage-pirenne.be/index.php?option=com_...  defacement         1
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement         1
#
#    url_len               pri_domain  letters_count  digits_count  \
# 0       16         br-icloud.com.br             13             0
# 1       35              mp3raid.com             29             1
# 2       31           bopsecrets.org             25             1
# 3       84        garage-pirenne.be             60             7
# 4      235  adventure-nicaragua.net            199            22
#
#    special_chars_count  shortened  abnormal_url  secure_http  have_ip  \
# 0                    3          0             0            0        0
# 1                    5          0             0            0        0
# 2                    5          0             0            0        0
# 3                   17          0             1            0        0
# 4                   14          0             1            0        0
#
#   url_region          root_domain
# 0     Brazil            br-icloud
# 1     Global              mp3raid
# 2     Global           bopsecrets
# 3    Belgium       garage-pirenne
# 4     Global  adventure-nicaragua

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

y_predicted = clf.predict(test_df)
